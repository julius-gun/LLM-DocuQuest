# %%
import os
import json
import logging
from typing import Dict, List
import time
from langchain.document_loaders import PyPDFLoader
from langchain.prompts import PromptTemplate
import google.generativeai as genai
import time
from google.api_core.exceptions import ResourceExhausted

os.environ["GOOGLE_API_KEY"] = "insert-code"  # Set before calling genai.configure()
# Configure Gemini
genai.configure(api_key=os.environ.get("insert-code"))
generation_config = {
    "temperature": 0,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 8192,  # Increased for potential longer responses
    "response_mime_type": "text/plain",
}
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro-002", generation_config=generation_config
)


# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


class QuestionGenerator:
    def __init__(self, pdf_path: str):
        """Initialize the question generator with the path to the PDF file."""
        self.pdf_path = pdf_path
        self.model = model  # Use the Gemini model

        # Template for question generation (same as before)
        self.qa_template = PromptTemplate(
            input_variables=["page_content", "page_number"],
            template="""
            You are an expert at creating technical questions and answers from documentation.
            Below is the content from page {page_number} of a technical manual.

            Content:
            {page_content}

            Create exactly ONE question and its corresponding answer based on specific factual information from this page.
            The question should be about important technical details, measurements, procedures, or specifications.

            Requirements:
            1. The answer must be found explicitly in the text
            2. The answer should be concise and specific
            3. For numerical values, include units
            4. Avoid questions about general concepts or definitions
            5. Focus on actionable information or specific parameters

            Respond in this exact JSON format:
            {{"question": "your question here", "answer": "your concise answer here"}}

            Response:
            """,
        )

    def load_pdf(self) -> List[dict]:
        """Load and process the PDF document."""
        try:
            loader = PyPDFLoader(self.pdf_path)
            pages = loader.load()
            
            processed_pages = []
            for page in pages:
                content = page.page_content
                page_num = page.metadata['page']
                processed_pages.append({
                    'content': content,
                    'page': page_num
                })
            return processed_pages
        except Exception as e:
            logger.error(f"Error loading PDF: {str(e)}")
            raise

    def generate_qa_pairs(self) -> Dict[str, List]:
        """Generate question-answer pairs for each page of the PDF."""
        pages = self.load_pdf()
        qa_pairs = {}

        for page in pages:
            try:
                # Skip pages with very little content
                if len(page['content'].strip()) < 200:
                    continue
                # skip pages 1 ... 22 and 142 ... 165
                if page['page'] < 23 or page['page'] > 141:
                    continue
                logger.info(f"Processing page {page['page']}")
                
                # Generate question and answer for the page
                prompt = self.qa_template.format(
                    page_content=page["content"], page_number=page["page"] + 1
                )
                retries = 0
                max_retries = 3  # Adjust as needed
                while retries < max_retries:
                    try:
                        response = self.model.generate_content(contents=[prompt])
                        generated_text = response.text

                        # Extract JSON string (Corrected Logic)
                        if generated_text.startswith("```json\n") and generated_text.endswith("```\n"):
                            json_string = generated_text[len("```json\n"):-len("```\n")]
                        elif generated_text.startswith("```json\n") and generated_text.endswith("```"):
                            json_string = generated_text[len("```json\n"):-len("```")]
                        else:
                            json_string = generated_text

                        # Parse JSON only ONCE (Corrected)
                        qa_data = json.loads(json_string)  # Use json_string here
                        question = qa_data["question"]
                        answer = qa_data["answer"]

                        qa_pairs[question] = [answer, page["page"] + 1]
                        time.sleep(0.5)  # Sleep to avoid rate limiting
                        break  
                    except ResourceExhausted as e:
                        retries += 1
                        wait_time = 4**retries  # Exponential backoff
                        logger.warning(f"Rate limited. Retrying in {wait_time} seconds...")
                        time.sleep(wait_time)
                    except Exception as e:  # Handle other errors
                        logger.error(f"Error processing page: {e}")
                        break  # Or retry as needed for other error types
                else:  # If the loop completes without a successful request
                    logger.error(f"Failed to process page after multiple retries.")

            except json.JSONDecodeError as e:
                logger.error(f"Failed to parse JSON: {e}  Raw response: {generated_text}")
                continue
            except Exception as e:
                logger.error(f"Error processing page {page['page'] + 1}: {str(e)}")
                continue

        return qa_pairs
    
    def save_qa_pairs(self, qa_pairs: Dict[str, List], output_file: str = "generated_qa_pairs.json"):
        """Save the generated QA pairs to a file."""
        try:
            with open(output_file, 'w') as f:
                json.dump(qa_pairs, f, indent=4)
            logger.info(f"Successfully saved QA pairs to {output_file}")
        except Exception as e:
            logger.error(f"Error saving QA pairs: {str(e)}")

def main():
    # Initialize generator
    pdf_path = "PDF/EN-A148703540-2.pdf"
    generator = QuestionGenerator(pdf_path)
    
    try:
        # Generate QA pairs
        qa_pairs = generator.generate_qa_pairs()
        
        # Print results
        print("\nGenerated Question-Answer Pairs:")
        print("=" * 50)
        for question, answer_info in qa_pairs.items():
            print(f"\nQuestion: {question}")
            print(f"Answer: {answer_info[0]}")
            print(f"Page: {answer_info[1]}")
        
        # Save results
        generator.save_qa_pairs(qa_pairs)
        
    except Exception as e:
        logger.error(f"Error in main execution: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Processing page 23
# INFO:__main__:Processing page 24
# INFO:__main__:Processing page 25
# INFO:__main__:Processing page 26
# INFO:__main__:Processing page 27
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# INFO:__main__:Processing page 28
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 29
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# INFO:__main__:Processing page 30
# INFO:__main__:Processing page 31
# INFO:__main__:Processing page 32
# INFO:__main__:Processing page 33
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# INFO:__main__:Processing page 34
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 35
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 36
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 37
# INFO:__main__:Processing page 38
# INFO:__main__:Processing page 39
# INFO:__main__:Processing page 40
# INFO:__main__:Processing page 41
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# INFO:__main__:Processing page 42
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 43
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 44
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 45
# INFO:__main__:Processing page 46
# INFO:__main__:Processing page 47
# INFO:__main__:Processing page 48
# INFO:__main__:Processing page 49
# INFO:__main__:Processing page 50
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 51
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 52
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 53
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# INFO:__main__:Processing page 54
# INFO:__main__:Processing page 55
# INFO:__main__:Processing page 56
# INFO:__main__:Processing page 57
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 58
# INFO:__main__:Processing page 59
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 60
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 61
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# INFO:__main__:Processing page 62
# INFO:__main__:Processing page 63
# INFO:__main__:Processing page 64
# INFO:__main__:Processing page 65
# INFO:__main__:Processing page 66
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 67
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 68
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 69
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# INFO:__main__:Processing page 70
# INFO:__main__:Processing page 71
# INFO:__main__:Processing page 72
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# INFO:__main__:Processing page 73
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# INFO:__main__:Processing page 74
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 75
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 76
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 77
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# INFO:__main__:Processing page 78
# INFO:__main__:Processing page 79
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# INFO:__main__:Processing page 80
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 81
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 82
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 83
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 84
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 85
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 86
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 87
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 88
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 89
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 90
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 91
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 92
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 93
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 94
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 95
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 96
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 97
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 98
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 99
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 100
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 101
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 102
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 103
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 104
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 105
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 106
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 107
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 108
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 109
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 110
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 111
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 112
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 113
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 114
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 115
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 116
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 117
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 118
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 119
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 120
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 121
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 122
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 123
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 124
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 125
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 126
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 127
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 128
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 129
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 130
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 131
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 132
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 133
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 134
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 135
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 136
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 137
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 138
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 139
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 140
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Processing page 141
# WARNING:__main__:Rate limited. Retrying in 2 seconds...
# WARNING:__main__:Rate limited. Retrying in 4 seconds...
# WARNING:__main__:Rate limited. Retrying in 8 seconds...
# ERROR:__main__:Failed to process page after multiple retries.
# INFO:__main__:Successfully saved QA pairs to generated_qa_pairs.json
# Generated Question-Answer Pairs:
# ==================================================
#
# Question: How many dosing openings are used in the fine application setting of the spreader, and how does this compare to the normal dosing setting?
# Answer: Two of the three dosing openings are closed during fine application, leaving one open.  Normal dosing utilizes all three openings.
# Page: 24
#
# Question: What is the maximum acceptable overlap percentage for a trapezoidal spreading pattern with the GEOSPREAD system?
# Answer: Less than 100%
# Page: 25
#
# Question: How is working width reduction visually represented on the main screen when using GEOCONTROL?
# Answer: By progressively removing portions of the black triangles representing the sections, and displaying the updated working width.
# Page: 26
#
# Question: What is the maximum number of measuring points used for a rate map when using the MULTIRATE functionality on an ISOBUS weighing spreader?
# Answer: 8 measuring points
# Page: 27
#
# Question: What percentage of overlap is achieved with a full field spreading pattern?
# Answer: 100%
# Page: 28
#
# Question: If a tractor lacks an ISOBUS connection, what hardware can be obtained from the dealer to enable connection with ISOBUS machines like this spreader?
# Answer: The universal IsoMatch terminal.
# Page: 30
#
# Question: How frequently does the spreader perform automatic calibration tests, and what are the two criteria that trigger these tests?
# Answer: The spreader performs automatic calibration tests every 75 kg of fertilizer spread or every minute, whichever comes first.
# Page: 31
#
# Question: How can the tractor's driving speed be transmitted to the IsoMatch if the tractor lacks ISOBUS communication?
# Answer: By adding the IsoMatch power cable set to the tractor.
# Page: 32
#
# Question: What are two examples of applications that can be run simultaneously on the split screen of the IsoMatch universal ISOBUS terminal?
# Answer: The main screen of the machine and a separate operating program.
# Page: 33
#
# Question: How long should the main switch button (located on the upper left in the red extension) be pressed to turn the control box on or off?
# Answer: At least 1 second.
# Page: 34
#
# Question: After initial setup and after any maintenance or repairs, how long should the machine be operated before re-checking all nuts and bolts?
# Answer: 1 hour
# Page: 38
#
# Question: How many plugs should be connected to the tractor's CAN connection when using an IsoMatch or other loose-standing ISO-control box with a tractor equipped with the ISOBUS communication system?
# Answer: 1 plug
# Page: 39
#
# Question: How should the console foot be mounted if no suitable mounting location exists in the cabin?
# Answer: A footplate should be made and welded to the pipe for the console foot.
# Page: 40
#
# Question: How many plugs are on the side of the CAN cable that connects to the IsoMatch control box when using an ISO tractor?
# Answer: 2 plugs
# Page: 41
#
# Question: What components are included with the hopper extension?
# Answer: 2 long sides, 2 short sides, 4 corner parts, 4 caps, and fixing material.
# Page: 42
#
# Question: What determines the working width of the spreading machine?
# Answer: The RPM of the spreading disc.
# Page: 46
#
# Question: Where should the position sensor for the hydraulic border spreading plate be connected?
# Answer: In the electronic box on the spreader.
# Page: 47
#
# Question: When mounting the support for the calibration container, how far back should the bolts on the turning rod be turned?
# Answer: 5 mm
# Page: 48
#
# Question: What category of three-point power lift is required for the tractor, and what is required if the tractor has a Cat. 3 or Cat. 4 power lift?
# Answer: The tractor must be equipped with a Cat. 2 three-point power lift.  If the tractor has a Cat. 3 or Cat. 4 power lift, a linkage frame (optional extra) is required.
# Page: 49
#
# Question: What specific precaution should be taken before working between the tractor and machine to check the coupling shaft length, and why?
# Answer: Place the machine on a supporting beam to prevent it from dropping and potentially causing serious injury if the power lift is inadvertently operated.
# Page: 50
#
# Question: What is the maximum permissible operating angle for the coupling shaft, both when lifted and lowered?
# Answer: 30°
# Page: 54
#
# Question: How should the control box be connected to the tractor's ISOBUS network?
# Answer: Connect an ISO plug with both CAN plugs on one side to the back of the control box, and connect the single CAN plug on the other side of the cable to the tractor's ISOBUS network connection. If the tractor has a tractor ECU, remove its CAN plug from the control box.
# Page: 55
#
# Question: What should be checked after connecting the machine to the tractor, and what action may be required?
# Answer: The machine should be checked for level and adjusted horizontally if needed using the lift rod and top link adjustments.
# Page: 56
#
# Question: What three physical properties of fertilizer must be determined to select the correct spreading chart?
# Answer: Type and pattern of granules, distribution (composition of granules of various sizes), and similar weight.
# Page: 57
#
# Question: What are the diameter ranges used by the distribution meter to classify fertilizer granules?
# Answer: Less than 2.0 mm, 2.0 - 3.3 mm, 3.3 - 4.75 mm, and greater than 4.75 mm.
# Page: 59
#
# Question: What specific precautions should be taken before filling, adjusting, or testing the spreader to prevent jamming and ensure safety?
# Answer: Switch the tractor off, remove the ignition keys, engage the parking brake, wait for all machine parts to stop moving, and never go under an elevated, unsecured spreader.
# Page: 62
#
# Question: What is the application rate of OCI Agro2 MM fertilizer in kg/ha when traveling at 7 km/h and using a spreader speed of 525 rpm?
# Answer: 262 kg/ha
# Page: 63
#
# Question: How can the working width of the spreader be adjusted?
# Answer: By selecting the correct connection point for the coupling shaft (with the PTO speed) and the discharge point.
# Page: 64
#
# Question: When using GEOCONTROL and the spreader inclination is set to 4° or 8°, how should the length B value in the machine data screen be adjusted?
# Answer: Increase length B by 10% at 4° and 20% at 8°.
# Page: 65
#
# Question: When using automatic calibration to determine the dosing setting for a constant application rate, what potential issue exists with the second automatic calibration and what is the recommended practice to mitigate this issue?
# Answer: The application rate for the second automatic calibration (approximately 2 minutes) could differ markedly from the selected application rate. It is recommended to use starting values from the spreading charts in the ‘Curve Calibration’ screen.
# Page: 66
#
# Question: If the desired application rate of Nutramon is 25 kg/ha with a working width of 27 meters and a driving speed of 8 km/h, what is the required flowrate?
# Answer: 9 kg/min
# Page: 70
#
# Question: How long should the spreader run to 'rinse' the calibration container before beginning the calibration test?
# Answer: 5 seconds
# Page: 71
#
# Question: What type of serial connection is used for communication between the spreader's control system and the IsoMatch control box, and where is it located on the control box?
# Answer: An RS 232 connection located at the back of the IsoMatch control box.
# Page: 72
#
# Question: What is the recommended practice regarding tractor cabin configuration when spreading fertilizer?
# Answer: Always work with a closed cabin with active carbon filters in the air inlets.
# Page: 73
#
# Question: When loading the spreader manually or with large bags, what is the maximum distance allowed between the hopper rim and the ground before a load platform becomes mandatory?
# Answer: 1250 mm
# Page: 74
#
# Question: When preparing the spreader for the spreading pattern test, at what distance apart should the troughs be placed to the right of the tractor tracks?
# Answer: 4 meters
# Page: 78
#
# Question: What is the minimum recommended application rate when spreading, and what unit is it measured in?
# Answer: 250 kg/ha
# Page: 79
#
# Question: What is the maximum acceptable percentage difference between the left and right spreading disc measurements before further adjustments are required?
# Answer: 3%
# Page: 80

# %%
# %pip install -qU langchain-google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.
