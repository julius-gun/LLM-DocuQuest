# %%
from langchain_ollama.llms import OllamaLLM
from langchain.document_loaders import PyPDFLoader
from langchain.prompts import PromptTemplate
import json
import logging
from typing import Dict, List
import time

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

class QuestionGenerator:
    def __init__(self, pdf_path: str):
        """Initialize the question generator with the path to the PDF file."""
        self.pdf_path = pdf_path
        self.llm = OllamaLLM(model="llama3.1")
        
        # Template for question generation
        self.qa_template = PromptTemplate(
            input_variables=["page_content", "page_number"],
            template="""
            You are an expert at creating technical questions and answers from documentation.
            Below is the content from page {page_number} of a technical manual.
            
            Content:
            {page_content}

            Create exactly ONE question and its corresponding answer based on specific factual information from this page.
            The question should be about important technical details, measurements, procedures, or specifications.
            
            Requirements:
            1. The answer must be found explicitly in the text
            2. The answer should be concise and specific
            3. For numerical values, include units
            4. Avoid questions about general concepts or definitions
            5. Focus on actionable information or specific parameters
            
            Respond in this exact JSON format:
            {{"question": "your question here", "answer": "your concise answer here"}}
            
            Response:
            """
        )

    def load_pdf(self) -> List[dict]:
        """Load and process the PDF document."""
        try:
            loader = PyPDFLoader(self.pdf_path)
            pages = loader.load()
            
            processed_pages = []
            for page in pages:
                content = page.page_content
                page_num = page.metadata['page']
                processed_pages.append({
                    'content': content,
                    'page': page_num
                })
            return processed_pages
        except Exception as e:
            logger.error(f"Error loading PDF: {str(e)}")
            raise

    def generate_qa_pairs(self) -> Dict[str, List]:
        """Generate question-answer pairs for each page of the PDF."""
        pages = self.load_pdf()
        qa_pairs = {}
        
        for page in pages:
            try:
                # Skip pages with very little content
                if len(page['content'].strip()) < 200:
                    continue
                # skip pages 1 ... 22 and 142 ... 165 as they are not useful
                if page['page'] < 23 or page['page'] > 141:
                    continue
                logger.info(f"Processing page {page['page']}")
                
                # Generate question and answer for the page
                prompt = self.qa_template.format(
                    page_content=page['content'],
                    page_number=page['page'] + 1  # Convert to 1-based page numbering
                )
                
                # Get response from model
                response = self.llm.invoke(prompt)
                
                try:
                    # Parse JSON response
                    qa_data = json.loads(response)
                    question = qa_data['question']
                    answer = qa_data['answer']
                    
                    # Store in the format requested
                    qa_pairs[question] = [answer, page['page'] + 1]
                    
                    # Add small delay to avoid overwhelming the model
                    time.sleep(0.5)
                    
                except json.JSONDecodeError:
                    logger.error(f"Failed to parse JSON response for page {page['page'] + 1}")
                    continue
                
            except Exception as e:
                logger.error(f"Error processing page {page['page'] + 1}: {str(e)}")
                continue
        
        return qa_pairs

    def save_qa_pairs(self, qa_pairs: Dict[str, List], output_file: str = "generated_qa_pairs.json"):
        """Save the generated QA pairs to a file."""
        try:
            with open(output_file, 'w') as f:
                json.dump(qa_pairs, f, indent=4)
            logger.info(f"Successfully saved QA pairs to {output_file}")
        except Exception as e:
            logger.error(f"Error saving QA pairs: {str(e)}")

def main():
    # Initialize generator
    pdf_path = "PDF/EN-A148703540-2.pdf"
    generator = QuestionGenerator(pdf_path)
    
    try:
        # Generate QA pairs
        qa_pairs = generator.generate_qa_pairs()
        
        # Print results
        print("\nGenerated Question-Answer Pairs:")
        print("=" * 50)
        for question, answer_info in qa_pairs.items():
            print(f"\nQuestion: {question}")
            print(f"Answer: {answer_info[0]}")
            print(f"Page: {answer_info[1]}")
        
        # Save results
        generator.save_qa_pairs(qa_pairs)
        
    except Exception as e:
        logger.error(f"Error in main execution: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Processing page 23
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 24
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 25
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 26
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 27
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 28
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 29
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 30
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 31
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 32
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 33
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 34
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 35
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 36
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 37
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 38
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 39
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 40
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 41
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 42
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 43
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 44
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 45
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 46
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 47
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 48
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 49
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 50
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 51
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 52
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 53
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 54
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 55
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 56
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 57
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 58
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 59
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 60
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 61
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 62
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 63
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 64
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 65
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 66
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 67
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 68
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 69
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 70
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 71
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 72
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 73
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 74
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# ERROR:__main__:Failed to parse JSON response for page 75
# INFO:__main__:Processing page 75
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 76
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 77
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 78
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 79
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 80
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 81
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 82
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 83
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 84
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 85
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 86
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 87
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 88
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 89
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 90
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 91
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 92
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 93
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 94
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 95
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 96
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 97
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 98
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 99
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 100
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 101
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# ERROR:__main__:Failed to parse JSON response for page 102
# INFO:__main__:Processing page 102
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 103
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 104
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 105
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 106
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 107
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 108
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 109
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 110
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 111
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 112
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 113
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 114
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 115
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 116
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 117
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 118
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 119
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 120
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 121
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 122
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 123
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 124
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 125
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 126
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 127
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 128
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 129
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 130
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 131
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 132
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 133
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 134
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 135
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 136
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 137
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 138
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 139
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 140
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Processing page 141
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:__main__:Successfully saved QA pairs to generated_qa_pairs.json
# Generated Question-Answer Pairs:
# ==================================================
#
# Question: How many dosing openings are closed when using the fine dosing setting?
# Answer: 2 of 3
# Page: 24
#
# Question: What is the maximum allowed percentage for an overlapping area when a trapezoidal spreading pattern results?
# Answer: less than 100%
# Page: 25
#
# Question: What is the working width reduction displayed per section in the main screen?
# Answer: 24 meters
# Page: 26
#
# Question: How many measuring points are supported by the rate map for MULTIRATE?
# Answer: 8
# Page: 27
#
# Question: What is the percentage overlap of the full field spreading pattern?
# Answer: 100%
# Page: 28
#
# Question: What is the width of the ExactLine for border spreading?
# Answer: 1/2 Working width
# Page: 29
#
# Question: What type of sensor measures the current required driving speed and localisation?
# Answer: gps sensor
# Page: 30
#
# Question: What is the time interval for automatic calibration tests by the spreader?
# Answer: every 75 kg or every minute
# Page: 31
#
# Question: What is required for the tractor to capture the speed signal from the tractor electronics if speed is not measured on the (trailed) machine?
# Answer: A special cable set.
# Page: 32
#
# Question: How many screens can be operated simultaneously on the IsoMatch control box?
# Answer: 2
# Page: 33
#
# Question: What is the recommended duration for pressing the main switch button to turn the control box on and off?
# Answer: At least 1 second.
# Page: 34
#
# Question: How many function buttons are there on the IsoMatch Grip?
# Answer: 11
# Page: 35
#
# Question: What is the maximum load capacity of the machine?
# Answer: 3900 kg
# Page: 36
#
# Question: What is the sound level of the tractor at 540 rpm with the spreader closed?
# Answer: 71.9 dB
# Page: 37
#
# Question: How often should you check that all nuts and bolts are well set after delivery, maintenance, or repairs have been carried out?
# Answer: After one hour of use
# Page: 38
#
# Question: What is the number of plugs that need to be attached to the control box when connecting it with a tractor CAN connection?
# Answer: 2
# Page: 39
#
# Question: What is the recommended swivel range for the console?
# Answer: 40 degrees
# Page: 40
#
# Question: How many plugs are attached to the side of the CAN cable for a NON-ISO tractor?
# Answer: 2
# Page: 41
#
# Question: How many corner parts are included in a hopper extension?
# Answer: 4
# Page: 42
#
# Question: What is the recommended torque for fastening the lock nuts that secure the vanes?
# Answer: 50NM
# Page: 43
#
# Question: What is the recommended torque for fastening the lock nuts?
# Answer: 50 NM
# Page: 44
#
# Question: What is the recommended assembly procedure for the mud guards?
# Answer: Also see the spare parts manual
# Page: 45
#
# Question: What is the typical way to determine the working width of the machine?
# Answer: The RPM of the spreading disc.
# Page: 46
#
# Question: What is required to connect the position sensor for the hydraulic border spreading plate?
# Answer: Please refer to the installation instructions for correct installation, and also see »Calibration container« on page 48.
# Page: 47
#
# Question: How far should the nuts on the bolts be turned back when preparing the calibration container?
# Answer: 5 mm
# Page: 48
#
# Question: What type of power lift is required for the tractor to operate the spreader?
# Answer: Cat. 2 three point power lift
# Page: 49
#
# Question: What is the length of the coupling shaft when the PTO shaft and machine drive axle are level?
# Answer: The shortest possible length.
# Page: 50
#
# Question: What is the minimum clearance required at the outer edges of the profiled tubes?
# Answer: 25 mm
# Page: 51
#
# Question: What is the prescribed overlap of the coupling shaft halves and protection sleeves, both in transport and operating position?
# Answer: not specified
# Page: 52
#
# Question: What is the maximum distance between the tractor and the spreader to ensure stability?
# Answer: 200 mm
# Page: 53
#
# Question: What is the maximum operating angle of the coupling shaft when lifted and lowered?
# Answer: 30°
# Page: 54
#
# Question: Where should the hydraulic hose be placed after connecting to prevent damage?
# Answer: so that it would not pinch or damage.
# Page: 55
#
# Question: What is the minimum requirement for the decoupling ropes of the quick coupling when connecting the power lift?
# Answer: The decoupling ropes must never be tense and provide sufficient freedom for movement, even with the power lift in the lowest position.
# Page: 56
#
# Question: What is the most vital characteristic of the fertiliser when it comes to spreading?
# Answer: Distribution
# Page: 57
#
# Question: What is the surface of a prill?
# Answer: very smooth
# Page: 58
#
# Question: What is the mesh width of each part in a distribution meter, as described in the text?
# Answer: 2.0 mm, 3.3 mm, and 4.75 mm.
# Page: 59
#
# Question: What is the minimum density of fertiliser desirable for a good distribution?
# Answer: 1 kg/l
# Page: 60
#
# Question: What is the procedure to access the online spreading chart service?
# Answer: Go to the website of the Kverneland Group at http://www.Kvernelands preadingcharts.com, select a product with comparable characteristics, and complete the required details.
# Page: 61
#
# Question: What is the recommended speed for setting the spreader?
# Answer: km/h
# Page: 62
#
# Question: What is the recommended spreading rate for OCI Agro2 MM?
# Answer: 3.3 kg/L
# Page: 63
#
# Question: What is the recommended procedure to select a working width for the spreader?
# Answer: Use the spreading chart book, online service, or mobile app to find the desired working width of the fertilizer type with similar properties.
# Page: 64
#
# Question: What is the typical angle of the spreader, and how can it be adjusted?
# Answer: The spreader is normally in the horizontal position. It may be necessary to adjust the spreader's angle with large working widths or with top dressing. The correct angle can be set by adjusting the top link.
# Page: 65
#
# Question: What is the recommended procedure to determine the application rate when using the control system's automatic calibration feature?
# Answer: Use the spreading charts, and take the starting values from the charts as they are more reliable than the results of a second automatic calibration.
# Page: 66
#
# Question: What is the recommended flowrate threshold for using fine application?
# Answer: less than 40 kg/min
# Page: 67
#
# Question: What is the factor used to calculate the flowrate when the selected application rate or driving speed is not indicated in the spreading chart?
# Answer: 3
# Page: 68
#
# Question: What is the recommended dosing setting for spreading slug pellets with a working width of 12 metres, a driving speed of 8 km/h and a selected application rate of 23 kg/ha?
# Answer: 12+1 (= 13)
# Page: 69
#
# Question: What is the required flowrate for spreading Nutramon with a working width of 27 metres, a driving speed of 8 km/h and a selected application rate of 25 kg/ha?
# Answer: 9 kg/min.
# Page: 70
#
# Question: How long should the spreader be allowed to spread for during the calibration test?
# Answer: 5 seconds
# Page: 71
#
# Question: What is the type of connection used for communication between the external system and the control box?
# Answer: RS 232 connection
# Page: 72
#
# Question: What is the recommended state for a machine during the filling process?
# Answer: in the power lift of the tractor
# Page: 73
#
# Question: What is the minimum distance that the machine must be lifted above the soil during loading?
# Answer: 10 cm
# Page: 74
#
# Question: What should be done before engaging with the spreader while filling, adjusting and testing it?
# Answer: Wear protective clothing and gloves, read the safety instructions provided by the supplier and follow their directions
# Page: 76
#
# Question: What is the maximum wind speed for performing the tray test?
# Answer: 3 m/s
# Page: 77
#
# Question: What is the recommended height of the spreader above the troughs?
# Answer: 75 cm
# Page: 78
#
# Question: What is the minimum application rate that should be entered with the selected driving speed?
# Answer: At least 250 kg/ha
# Page: 79
#
# Question: What percentage difference is considered too great between the measuring tubes on the left and right spreading discs?
# Answer: 3%
# Page: 80
#
# Question: What is the recommended height of the spreading disc above the troughs?
# Answer: 75 cm
# Page: 81
#
# Question: What is the recommended minimum application rate for spreading?
# Answer: 250 kg/ha
# Page: 82
#
# Question: What is the maximum allowed difference between the content of separate tubes and the average?
# Answer: 15%
# Page: 83
#
# Question: What is the correct height of the spreading disc when using the border spreading plate?
# Answer: 75 cm above the troughs
# Page: 84
#
# Question: What is the correct PTO shaft rpm for border spreading?
# Answer: 400 rpm
# Page: 85
#
# Question: What positions are indicated in the H2O spreading chart?
# Answer: A to D
# Page: 86
#
# Question: What is the maximum acceptable percentage of fertiliser quantity allowed in the first trough?
# Answer: 10%
# Page: 87
#
# Question: What should be done if the difference between the middle measuring tube and the outer graduated tubes in border spreading is more than 25%?
# Answer: Increase the spreading disc rpm by 50 rpm.
# Page: 88
#
# Question: What is the recommended height of the spreading disc for ExactLine testing?
# Answer: 75 cm above the troughs
# Page: 89
#
# Question: What is the minimum distance to be driven over the troughs after spreading has stopped?
# Answer: At least one working width, e.g. 18 or 24 meters
# Page: 90
#
# Question: What is the maximum acceptable loss in the ditch, according to environmental standards?
# Answer: 10%
# Page: 91
#
# Question: What is the speed limit for motor vehicles with a limited speed indicator?
# Answer: <40km/h
# Page: 92
#
# Question: What should be checked before lowering the power lift while moving?
# Answer: Lock the control lever of the power lift.
# Page: 93
#
# Question: What should you do before leaving the tractor?
# Answer: Switch the PTO shaft off, release the pressure from the hydraulic system, switch the electronic control system off, switch the tractor off, remove the key from the ignition, and engage the parking brake of the tractor.
# Page: 94
#
# Question: What is the minimum distance from the bottom of the vanes to the ground or crop level for proper spreader function?
# Answer: 75 cm
# Page: 95
#
# Question: What is the recommended height over the ground or crops for the spreader?
# Answer: 75 cm
# Page: 96
#
# Question: What is the recommended width of a headland to ensure good distribution and connection before turning?
# Answer: A broad or double headland, typically with a triangular spreading pattern
# Page: 97
#
# Question: What is the recommended distance from the field edge when setting the first way for boundary track spreading with ExactLine?
# Answer: 1/2 X meter
# Page: 98
#
# Question: What is the correct path setting for the hydraulic border spreading plate when doing one-sided boundary spreading?
# Answer: half the working width of Situation A
# Page: 99
#
# Question: What is the recommended overlap percentage for the headland connection?
# Answer: 50%
# Page: 100
#
# Question: What is the minimum hopper capacity for automatic calibration at low doses?
# Answer: -15 kg
# Page: 101
#
# Question: What is the recommended distance to stop spreading when approaching the end of a land without GEOCONTROL headland?
# Answer: Half a working width.
# Page: 103
#
# Question: What should be done with the spreading discs when stopping at the end of a property without GEOCONTROL?
# Answer: Let them turn and do not switch off the PTO shaft.
# Page: 104
#
# Question: What is the effect of spreading in a triangular pattern with small working widths?
# Answer: The first and second passes of the spreading patterns overlap each other completely.
# Page: 105
#
# Question: What is the method for boundary track spreading with ExactLine?
# Answer: drive down the first sprayer tramline from the field edge and spray in the direction of the border
# Page: 106
#
# Question: What is the maximum acceptable percentage of fertiliser spread beyond the field edge?
# Answer: 10%
# Page: 107
#
# Question: What is the correct rpm of the spreading discs for border spreading?
# Answer: the value of the relevant spreading chart
# Page: 108
#
# Question: What is the recommended distance from the field edge to drive the first path with the middle of the tractor?
# Answer: 2 metres
# Page: 109
#
# Question: What is the maximum acceptable loss over the field edge when using ExactLine for boundary track spreading?
# Answer: 10% of the quantity distributed in the centre behind the spreader (100%)
# Page: 110
#
# Question: How long should the single-acting hydraulic valve be run to engage the ExactLine?
# Answer: a few seconds
# Page: 111
#
# Question: What is the recommended driving pattern when using the ExactLine?
# Answer: Drive in the first sprayer tramline or half the working width (1/2 × meter) from the field edge.
# Page: 112
#
# Question: What should be done before approaching the spreader after it has come to a standstill?
# Answer: Wait for all machine parts to come to a standstill.
# Page: 113
#
# Question: How long should you leave the fertiliser in the spreader?
# Answer: a long period of time
# Page: 114
#
# Question: What page should you refer to for instructions on preparing the machine to be transported?
# Answer: page 93
# Page: 115
#
# Question: What should you do if opening the filters to reduce an encrusted layer of fertiliser blocks them, preventing unwanted closing?
# Answer: Block them to prevent unwanted closing.
# Page: 116
#
# Question: What is the maximum temperature allowed for cleaning the machine?
# Answer: 40°C
# Page: 117
#
# Question: What should be avoided when using a high-pressure cleaner to clean the machine?
# Answer: Aiming it at the seals and breathers.
# Page: 121
#
# Question: What is the required condition for disconnecting the machine?
# Answer: the hopper must be empty
# Page: 119
#
# Question: What is the maximum distance to drive the tractor forward when preparing to store the machine?
# Answer: 200 mm
# Page: 120
#
# Question: What should be done with bigger or heavier parts when being replaced?
# Answer: They must be locked and secured to lifting gear.
# Page: 122
#
# Question: What should be checked after one hour of machine use?
# Answer: all the nuts and bolts
# Page: 123
#
# Question: What is the recommended quantity of gear grease for the central gearbox?
# Answer: 2 x 0.25 litres EP00/000 gear grease
# Page: 124
#
# Question: How often should you check the hydraulic system?
# Answer: every 100 hours
# Page: 125
#
# Question: How many grease nipples are provided for the actuators?
# Answer: 1 nipple
# Page: 126
#
# Question: What is the minimum grease level required under the spreading discs' gearbox?
# Answer: 35 mm
# Page: 127
#
# Question: What should be applied to the drive axles and connectors?
# Answer: A suitable lubricant.
# Page: 128
#
# Question: What is the recommended torque for a M10 hexagon bolt with a quality of 8.8 and a friction coefficient of 0.13?
# Answer: 9 Nm
# Page: 129
#
# Question: What is the recommended torque for an M10 hexagon bolt with a friction coefficient of 0.30?
# Answer: 59.3 Nm
# Page: 130
#
# Question: What is the maximum hydraulic pressure that should not be exceeded?
# Answer: 210 bars
# Page: 131
#
# Question: What is the maximum storage and operating limit for hydraulic hoses?
# Answer: exceeding the storage and the operating limits
# Page: 132
#
# Question: How often should the dosing mechanism settings be checked?
# Answer: after the first 10 running hours, for each season, after every 100 operational hours
# Page: 133
#
# Question: What is the required position of the dosing mechanism above the spreading discs?
# Answer: exactly in the middle
# Page: 134
#
# Question: What is the minimum gap between dosing baffles to ensure correct dosing?
# Answer: a small crack of light
# Page: 135
#
# Question: What is the correct distance between the inside of the rope and the opening of the discharge bushing?
# Answer: 109 mm
# Page: 136
#
# Question: What distance between the inside of the rope and the opening of the discharge bushing should be measured?
# Answer: 109 mm
# Page: 137
#
# Question: What is the correct distance between the discharge bushing and the spreading disc?
# Answer: 1.0 mm
# Page: 138
#
# Question: What is the required distance between the discharge bush and the spreading disc?
# Answer: 1.0 mm
# Page: 139
#
# Question: How often must the agitator axle seal be replaced?
# Answer: every season, as well as after every 100 operational hours
# Page: 140
#
# Question: How many fastening bolts need to be removed from the seal rings?
# Answer: 3
# Page: 141
#
# Question: What is the name of the status bar that displays time, GPS signal strength, and driving direction?
# Answer: Status bar
# Page: 142
